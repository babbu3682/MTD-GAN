# %%
# !pip install pretrainedmodels==0.7.4
# !pip install efficientnet-pytorch==0.6.3
# !pip install timm==0.3.2

# %%
# CUDA 11.1
# !pip install torch==1.8.0 torchvision==0.9.0 torchaudio==0.8.0

# %%
# !pip uninstall -y monai

# %%
# !pip install monai

# %%
# RMSE -> MAE Loss 꿀팁!!

# %%
# !nvidia-smi

import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="3"
# Out:
# Mon Nov 15 05:52:26 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.73.01    Driver Version: 460.73.01    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  TITAN RTX           Off  | 00000000:02:00.0 Off |                  N/A |
# | 75%   85C    P2   169W / 280W |  21232MiB / 24220MiB |     85%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# ...

# %%
cd /workspace/sunggu/4.Dose_img2img/scripts study
# Out:
# /workspace/sunggu/4.Dose_img2img/scripts study

# %%
import torch
print(torch.__version__)
# Out:
# 1.8.0+cu111

# %%
import multiprocessing
print("CPU 갯수 = ", multiprocessing.cpu_count())
# Out:
# CPU 갯수 =  32

# %% [markdown]
# # MAP_NN

# %% [markdown]
# ##### Resume

# %%
# !python train.py \
--batch-size 32 \
--epochs 20000 \
--min-lr 5e-6 \
--lr 2e-4 \
--data-set 'Sinogram_DCM' \
--model-name 'MAP_NN' \
--criterion 'L1 Loss' \
--output_dir '/workspace/sunggu/4.Dose_img2img/model/[Privious]MAP_NN_test2' \
--save_dir '/workspace/sunggu/4.Dose_img2img/Predictions/Train/png/[Privious]MAP_NN_test2/low2high/' \
--validate-every 1 \
--num_workers 4 \
--criterion_mode 'not balance' \
--teacher_forcing "False" \
--patch_training "True" \
--multi-gpu-mode 'Single'

# --resume '/workspace/sunggu/4.Dose_img2img/model/[Privious]MAP_NN/epoch_900_checkpoint.pth'
# --multi-gpu-mode 'DataParallel' \
# Out:
# inintializing...!
# inintializing...!
# inintializing...!
# inintializing...!
# inintializing...!
# inintializing...!
# inintializing...!
# inintializing...!
# inintializing...!
# inintializing...!
# inintializing...!
# inintializing...!
# inintializing...!
# ***********************************************
# ***********************************************
# Dataset Name:  Sinogram_DCM
# ---------- Model ----------
# Resume From:
# Output To:  /workspace/sunggu/4.Dose_img2img/model/[Privious]MAP_NN_test2
# Save   To:  /workspace/sunggu/4.Dose_img2img/Predictions/Train/png/[Privious]MAP_NN_test2/low2high/
# ---------- Optimizer ----------
# Learning Rate:  0.0002
# Weight Decay:  0.05
# Batchsize:  32
# Loading dataset ....
# Train [Total]  number =  6899
# Valid [Total]  number =  14
# Creating model: MAP_NN
# Number of Learnable Params: 17985537
# Start training for 20000 epochs
# ...

# %%
논문 읽고 구현 E-former / SACNN 까지만 해보기.

# %% [markdown]
# # Window 버전

# %%
# !python train.py \
--batch-size 32 \
--epochs 20000 \
--min-lr 5e-6 \
--lr 2e-4 \
--data-set 'Sinogram_DCM' \
--model-name 'MAP_NN' \
--criterion 'L1 Loss' \
--output_dir '/workspace/sunggu/4.Dose_img2img/model/[Privious]MAP_NN_window' \
--save_dir '/workspace/sunggu/4.Dose_img2img/Predictions/Train/png/[Privious]MAP_NN_window/low2high/' \
--validate-every 1 \
--num_workers 4 \
--criterion_mode 'not balance' \
--teacher_forcing "False" \
--patch_training "True" \
--multi-gpu-mode 'Single'

# --resume '/workspace/sunggu/4.Dose_img2img/model/[Privious]MAP_NN/epoch_900_checkpoint.pth'
# --multi-gpu-mode 'DataParallel' \
# Out:
# inintializing...!
# inintializing...!
# inintializing...!
# inintializing...!
# inintializing...!
# inintializing...!
# inintializing...!
# inintializing...!
# inintializing...!
# inintializing...!
# inintializing...!
# inintializing...!
# inintializing...!
# ***********************************************
# ***********************************************
# Dataset Name:  Sinogram_DCM
# ---------- Model ----------
# Resume From:
# Output To:  /workspace/sunggu/4.Dose_img2img/model/[Privious]MAP_NN_window
# Save   To:  /workspace/sunggu/4.Dose_img2img/Predictions/Train/png/[Privious]MAP_NN_window/low2high/
# ---------- Optimizer ----------
# Learning Rate:  0.0002
# Weight Decay:  0.05
# Batchsize:  32
# Loading dataset ....
# Train [Total]  number =  6899
# Valid [Total]  number =  14
# Creating model: MAP_NN
# Number of Learnable Params: 17985537
# Start training for 20000 epochs
# ...
