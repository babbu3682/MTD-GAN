# %%
# !pip install pretrainedmodels==0.7.4
# !pip install efficientnet-pytorch==0.6.3
# !pip install timm==0.3.2

# %%
# # CUDA 11.1
# !pip install torch==1.8.0 torchvision==0.9.0 torchaudio==0.8.0

# %%
# !pip install torch==1.8.0+cu111 torchvision==0.9.0+cu111 torchaudio==0.8.0 -f https://download.pytorch.org/whl/torch_stable.html

# %%
1.10.0+cu102

# %%
# RMSE -> MAE Loss 꿀팁!!

# %%
# !nvidia-smi

import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="3"
# Out:
# Fri Feb 18 10:22:23 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.91.03    Driver Version: 460.91.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Quadro RTX 8000     Off  | 00000000:1B:00.0 Off |                  Off |
# | 33%   44C    P2   252W / 260W |  47956MiB / 48601MiB |    100%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# ...

# %%
cd /workspace/sunggu/4.Dose_img2img/LowDose_HighDose_Code_Factory/scripts study
# Out:
# /workspace/sunggu/4.Dose_img2img/LowDose_HighDose_Code_Factory/scripts study

# %%
import torch
print(torch.__version__)
# Out:
# 1.10.0+cu102

# %%
import multiprocessing
print("CPU 갯수 = ", multiprocessing.cpu_count())
# Out:
# CPU 갯수 =  64

# %% [markdown]
# # SA_CNN_AutoEncoder

# %% [markdown]
# ## 64x64 Patch 2D based Learning

# %%
# !python train.py \
--batch-size 160 \
--epochs 1000 \
--lr_scheduler "lambda" \
--lr 1e-4 \
--data-set 'Sinogram_DCM' \
--model-name 'SACNN_AutoEncoder' \
--criterion 'L2 Loss' \
--output_dir '/workspace/sunggu/4.Dose_img2img/model/[Privious]SACNN_AutoEncoder_NEW' \
--save_dir '/workspace/sunggu/4.Dose_img2img/Predictions/Train/png/[Privious]SACNN_AutoEncoder_NEW/low2high/' \
--validate-every 2 \
--num_workers 4 \
--criterion_mode 'not balance' \
--multiple_GT "False" \
--patch_training "True" \
--multi-gpu-mode 'Single'
# Out:
# ***********************************************
# ***********************************************
# Dataset Name:  Sinogram_DCM
# ---------- Model ----------
# Resume From:
# Output To:  /workspace/sunggu/4.Dose_img2img/model/[Privious]SACNN_AutoEncoder_NEW
# Save   To:  /workspace/sunggu/4.Dose_img2img/Predictions/Train/png/[Privious]SACNN_AutoEncoder_NEW/low2high/
# ---------- Optimizer ----------
# Learning Rate:  0.0001
# Batchsize:  160
# Loading dataset ....
# Train [Total]  number =  6899
# Valid [Total]  number =  14
# Creating criterion: L2 Loss
# Creating model: SACNN_AutoEncoder
# Number of Learnable Params: 4145231
# AutoEncoder_2D(
#   (lay1): AE_Conv2D_Block(
#     (conv): Sequential(
#       (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# ...

# %% [markdown]
# ## Window 버전

# %%
# !python train.py \
--batch-size 34 \
--epochs 20000 \
--warmup-init-lr 1e-6 \
--min-lr 1e-6 \
--warmup-epochs 5 \
--lr 2e-4 \
--data-set 'Sinogram_DCM' \
--model-name 'SACNN_AutoEncoder' \
--criterion 'L2 Loss' \
--output_dir '/workspace/sunggu/4.Dose_img2img/model/[Privious]SACNN_AutoEncoder_2D_window' \
--save_dir '/workspace/sunggu/4.Dose_img2img/Predictions/Train/png/[Privious]SACNN_AutoEncoder_2D_window/low2high/' \
--validate-every 1 \
--num_workers 4 \
--criterion_mode 'not balance' \
--teacher_forcing "False" \
--patch_training "False" \
--multi-gpu-mode 'Single'

# --resume '/workspace/sunggu/4.Dose_img2img/model/[Privious]SACNN_AutoEncoder/epoch_999_checkpoint.pth'
# --multi-gpu-mode 'DataParallel' \
# Out:
# inintializing...!
# inintializing...!
# inintializing...!
# inintializing...!
# inintializing...!
# inintializing...!
# inintializing...!
# inintializing...!
# inintializing...!
# inintializing...!
# inintializing...!
# inintializing...!
# inintializing...!
# ***********************************************
# ***********************************************
# Dataset Name:  Sinogram_DCM
# ---------- Model ----------
# Resume From:
# Output To:  /workspace/sunggu/4.Dose_img2img/model/[Privious]SACNN_AutoEncoder_2D_window
# Save   To:  /workspace/sunggu/4.Dose_img2img/Predictions/Train/png/[Privious]SACNN_AutoEncoder_2D_window/low2high/
# ---------- Optimizer ----------
# Learning Rate:  0.0002
# Weight Decay:  0.05
# Batchsize:  34
# Loading dataset ....
# Train [Total]  number =  6899
# Valid [Total]  number =  14
# Creating model: SACNN_AutoEncoder
# Number of Learnable Params: 4753793
# Start training for 20000 epochs
# ...

# %% [markdown]
# # SA_CNN

# %%
# !python train.py \
--batch-size 4 \
--epochs 20000 \
--min-lr 5e-6 \
--lr 2e-4 \
--data-set 'Sinogram_NII' \
--model-name 'SACNN' \
--criterion 'L2 Loss' \
--output_dir '/workspace/sunggu/4.Dose_img2img/model/[Privious]SACNN' \
--save_dir '/workspace/sunggu/4.Dose_img2img/Predictions/Train/png/[Privious]SACNN/low2high/' \
--validate-every 1 \
--num_workers 4 \
--criterion_mode 'not balance' \
--teacher_forcing "False" \
--patch_training "True" \
--multi-gpu-mode 'Single' \
--resume '/workspace/sunggu/4.Dose_img2img/model/[Privious]SACNN/epoch_999_checkpoint.pth'

# --multi-gpu-mode 'DataParallel' \
# Out:
# ***********************************************
# ***********************************************
# Dataset Name:  Sinogram_NII
# ---------- Model ----------
# Resume From:  /workspace/sunggu/4.Dose_img2img/model/[Privious]SACNN/epoch_999_checkpoint.pth
# Output To:  /workspace/sunggu/4.Dose_img2img/model/[Privious]SACNN
# Save   To:  /workspace/sunggu/4.Dose_img2img/Predictions/Train/png/[Privious]SACNN/low2high/
# ---------- Optimizer ----------
# Learning Rate:  0.0002
# Weight Decay:  0.05
# Batchsize:  4
# Loading dataset ....
# Train [Total]  number =  115
# Valid [Total]  number =  1
# Creating model: SACNN
# Number of Learnable Params: 33064918
# Loading pre-trained Weight...!
# Traceback (most recent call last):
#   File "train.py", line 324, in <module>
#     main(args)
#   File "train.py", line 153, in main
#     model.load_state_dict(checkpoint['model_state_dict'])
# ...

# %%
# !python train.py \
--batch-size 4 \
--epochs 20000 \
--min-lr 5e-6 \
--lr 2e-4 \
--data-set 'Sinogram_NII' \
--model-name 'SACNN' \
--criterion 'L2 Loss' \
--output_dir '/workspace/sunggu/4.Dose_img2img/model/[Privious]SACNN_test' \
--save_dir '/workspace/sunggu/4.Dose_img2img/Predictions/Train/png/[Privious]SACNN_test/low2high/' \
--validate-every 1 \
--num_workers 4 \
--criterion_mode 'not balance' \
--teacher_forcing "False" \
--patch_training "True" \
--multi-gpu-mode 'Single'

# --multi-gpu-mode 'DataParallel' \
# Out:
# ***********************************************
# ***********************************************
# Dataset Name:  Sinogram_NII
# ---------- Model ----------
# Resume From:
# Output To:  /workspace/sunggu/4.Dose_img2img/model/[Privious]SACNN_test
# Save   To:  /workspace/sunggu/4.Dose_img2img/Predictions/Train/png/[Privious]SACNN_test/low2high/
# ---------- Optimizer ----------
# Learning Rate:  0.0002
# Weight Decay:  0.05
# Batchsize:  4
# Loading dataset ....
# Train [Total]  number =  115
# Valid [Total]  number =  1
# Creating model: SACNN
# Number of Learnable Params: 33064918
# Start training for 20000 epochs
# Train: [epoch:0]  [ 0/28]  eta: 0:05:35  lr: 0.000000  g_loss: 0.1721 (0.1721)  d_loss: 9.9907 (9.9907)  p_loss: 1.7021 (1.7021)  gp_loss: 9.9907 (9.9907)  time: 11.9828  data: 6.7155  max mem: 30088
# ...
