# %%
# !pip install pretrainedmodels==0.7.4
# !pip install efficientnet-pytorch==0.6.3
# !pip install timm==0.3.2

# %%
# # CUDA 11.1
# !pip install torch==1.8.0 torchvision==0.9.0 torchaudio==0.8.0

# %%
# RMSE -> MAE Loss 꿀팁!!

# %%
# !nvidia-smi

import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="3"
# Out:
# Sat Nov 20 12:49:11 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.73.01    Driver Version: 460.73.01    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  TITAN RTX           Off  | 00000000:02:00.0 Off |                  N/A |
# | 41%   50C    P0    68W / 280W |      0MiB / 24220MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# ...

# %%
cd /workspace/sunggu/4.Dose_img2img/scripts study
# Out:
# /workspace/sunggu/4.Dose_img2img/scripts study

# %%
import torch
print(torch.__version__)
# Out:
# 1.8.0+cu111

# %%
import multiprocessing
print("CPU 갯수 = ", multiprocessing.cpu_count())
# Out:
# CPU 갯수 =  32

# %% [markdown]
# # WGAN_VGG

# %%
# !python train.py \
--batch-size 160 \
--epochs 20000 \
--min-lr 5e-6 \
--lr 2e-4 \
--data-set 'Sinogram_DCM' \
--model-name 'WGAN_VGG' \
--criterion 'L1 Loss' \
--output_dir '/workspace/sunggu/4.Dose_img2img/model/[Privious]WGAN_VGG_test' \
--save_dir '/workspace/sunggu/4.Dose_img2img/Predictions/Train/png/[Privious]WGAN_VGG_test/low2high/' \
--validate-every 1 \
--num_workers 4 \
--criterion_mode 'not balance' \
--teacher_forcing "False" \
--patch_training "True" \
--multi-gpu-mode 'Single'

# --multi-gpu-mode 'DataParallel' \
# Out:
# ......Please set the path of AE!......
# Ae set done, Loading...
# Load model:/workspace/sunggu/4.Dose_img2img/model/[Privious]SACNN_AutoEncoder/epoch_999_checkpoint.pth
# Ae Reload!
#
# ***********************************************
# ***********************************************
# Dataset Name:  Sinogram_DCM
# ---------- Model ----------
# Resume From:
# Output To:  /workspace/sunggu/4.Dose_img2img/model/[Privious]WGAN_VGG_test
# Save   To:  /workspace/sunggu/4.Dose_img2img/Predictions/Train/png/[Privious]WGAN_VGG_test/low2high/
# ---------- Optimizer ----------
# Learning Rate:  0.0002
# Weight Decay:  0.05
# Batchsize:  160
# Loading dataset ....
# Train [Total]  number =  6899
# Valid [Total]  number =  14
# Creating model: WGAN_VGG
# Number of Learnable Params: 27780386
# Start training for 20000 epochs
# ...

# %% [markdown]
# ##### Resume

# %%
# !python train.py \
--batch-size 160 \
--epochs 1000 \
--min-lr 5e-6 \
--lr 2e-4 \
--data-set 'Sinogram_DCM' \
--model-name 'WGAN_VGG' \
--criterion 'L1 Loss' \
--output_dir '/workspace/sunggu/4.Dose_img2img/model/[Privious]WGAN_VGG' \
--save_dir '/workspace/sunggu/4.Dose_img2img/Predictions/Train/png/[Privious]WGAN_VGG/low2high/' \
--validate-every 1 \
--num_workers 4 \
--criterion_mode 'not balance' \
--teacher_forcing "False" \
--patch_training "True" \
--multi-gpu-mode 'Single' \
--resume '/workspace/sunggu/4.Dose_img2img/model/[Privious]WGAN_VGG/epoch_841_checkpoint.pth'
# --multi-gpu-mode 'DataParallel' \
# Out:
# ......Please set the path of AE!......
# Ae set done, Loading...
# Load model:/workspace/sunggu/4.Dose_img2img/model/[Privious]SACNN_AutoEncoder/epoch_999_checkpoint.pth
# Ae Reload!
#
# ***********************************************
# ***********************************************
# Dataset Name:  Sinogram_DCM
# ---------- Model ----------
# Resume From:  /workspace/sunggu/4.Dose_img2img/model/[Privious]WGAN_VGG/epoch_841_checkpoint.pth
# Output To:  /workspace/sunggu/4.Dose_img2img/model/[Privious]WGAN_VGG
# Save   To:  /workspace/sunggu/4.Dose_img2img/Predictions/Train/png/[Privious]WGAN_VGG/low2high/
# ---------- Optimizer ----------
# Learning Rate:  0.0002
# Weight Decay:  0.05
# Batchsize:  160
# Loading dataset ....
# Train [Total]  number =  6899
# Valid [Total]  number =  14
# Creating model: WGAN_VGG
# Number of Learnable Params: 27780386
# Loading pre-trained Weight...!
# Start training for 1000 epochs
# ...

# %% [markdown]
# # Window version

# %%
# !python train.py \
--batch-size 160 \
--epochs 20000 \
--min-lr 5e-6 \
--lr 2e-4 \
--data-set 'Sinogram_DCM' \
--model-name 'WGAN_VGG' \
--criterion 'L1 Loss' \
--output_dir '/workspace/sunggu/4.Dose_img2img/model/[Privious]WGAN_VGG_window' \
--save_dir '/workspace/sunggu/4.Dose_img2img/Predictions/Train/png/[Privious]WGAN_VGG_window/low2high/' \
--validate-every 1 \
--num_workers 4 \
--criterion_mode 'not balance' \
--teacher_forcing "False" \
--patch_training "True" \
--multi-gpu-mode 'Single' 
# --multi-gpu-mode 'DataParallel' \
# Out:
# inintializing...!
# inintializing...!
# inintializing...!
# inintializing...!
# inintializing...!
# inintializing...!
# inintializing...!
# inintializing...!
# inintializing...!
# inintializing...!
# inintializing...!
# inintializing...!
# inintializing...!
# ***********************************************
# ***********************************************
# Dataset Name:  Sinogram_DCM
# ---------- Model ----------
# Resume From:
# Output To:  /workspace/sunggu/4.Dose_img2img/model/[Privious]WGAN_VGG_window
# Save   To:  /workspace/sunggu/4.Dose_img2img/Predictions/Train/png/[Privious]WGAN_VGG_window/low2high/
# ---------- Optimizer ----------
# Learning Rate:  0.0002
# Weight Decay:  0.05
# Batchsize:  160
# Loading dataset ....
# Train [Total]  number =  6899
# Valid [Total]  number =  14
# Creating model: WGAN_VGG
# Number of Learnable Params: 27780386
# Start training for 20000 epochs
# ...

# %% [markdown]
# # Real Version -> lr=1e-5, Adam=[0.5,0.9], patch=80x80, 10장

# %%
# !python train.py \
--batch-size 80 \
--epochs 20000 \
--min-lr 5e-6 \
--lr 1e-5 \
--data-set 'Sinogram_DCM' \
--model-name 'WGAN_VGG' \
--criterion 'L1 Loss' \
--output_dir '/workspace/sunggu/4.Dose_img2img/model/[Privious]WGAN_VGG_Real' \
--save_dir '/workspace/sunggu/4.Dose_img2img/Predictions/Train/png/[Privious]WGAN_VGG_Real/low2high/' \
--validate-every 1 \
--num_workers 4 \
--criterion_mode 'not balance' \
--multiple_GT "False" \
--patch_training "True" \
--multi-gpu-mode 'Single' 
# --multi-gpu-mode 'DataParallel' \
# Out:
# inintializing...!
# inintializing...!
# inintializing...!
# inintializing...!
# inintializing...!
# inintializing...!
# inintializing...!
# inintializing...!
# inintializing...!
# inintializing...!
# inintializing...!
# inintializing...!
# inintializing...!
# inintializing...!
# inintializing...!
# ***********************************************
# ***********************************************
# Dataset Name:  Sinogram_DCM
# ---------- Model ----------
# Resume From:
# Output To:  /workspace/sunggu/4.Dose_img2img/model/[Privious]WGAN_VGG_Real
# Save   To:  /workspace/sunggu/4.Dose_img2img/Predictions/Train/png/[Privious]WGAN_VGG_Real/low2high/
# ---------- Optimizer ----------
# Learning Rate:  1e-05
# Weight Decay:  0.05
# Batchsize:  80
# Loading dataset ....
# Train [Total]  number =  6899
# Valid [Total]  number =  14
# Creating model: WGAN_VGG
# Number of Learnable Params: 27780386
# Start training for 20000 epochs
# ...

# %% [markdown]
# # Debugging

# %%
import glob

glob.glob('/workspace/sunggu/4.Dose_img2img/model/*WGAN_VGG_test/*')
# Out:
# ['/workspace/sunggu/4.Dose_img2img/model/[Privious]WGAN_VGG_test/epoch_0_checkpoint.pth',
#  '/workspace/sunggu/4.Dose_img2img/model/[Privious]WGAN_VGG_test/log.txt',
#  '/workspace/sunggu/4.Dose_img2img/model/[Privious]WGAN_VGG_test/epoch_1_checkpoint.pth',
#  '/workspace/sunggu/4.Dose_img2img/model/[Privious]WGAN_VGG_test/epoch_2_checkpoint.pth',
#  '/workspace/sunggu/4.Dose_img2img/model/[Privious]WGAN_VGG_test/epoch_3_checkpoint.pth',
#  '/workspace/sunggu/4.Dose_img2img/model/[Privious]WGAN_VGG_test/epoch_4_checkpoint.pth',
#  '/workspace/sunggu/4.Dose_img2img/model/[Privious]WGAN_VGG_test/epoch_5_checkpoint.pth',
#  '/workspace/sunggu/4.Dose_img2img/model/[Privious]WGAN_VGG_test/epoch_6_checkpoint.pth',
#  '/workspace/sunggu/4.Dose_img2img/model/[Privious]WGAN_VGG_test/epoch_7_checkpoint.pth',
#  '/workspace/sunggu/4.Dose_img2img/model/[Privious]WGAN_VGG_test/epoch_8_checkpoint.pth',
#  '/workspace/sunggu/4.Dose_img2img/model/[Privious]WGAN_VGG_test/epoch_9_checkpoint.pth',
# ...

# %%
# !python train.py \
--batch-size 160 \
--epochs 20000 \
--min-lr 5e-6 \
--lr 2e-4 \
--data-set 'Sinogram_DCM' \
--model-name 'WGAN_VGG' \
--criterion 'L1 Loss' \
--output_dir '/workspace/sunggu/4.Dose_img2img/model/[Privious]WGAN_VGG_test' \
--save_dir '/workspace/sunggu/4.Dose_img2img/Predictions/Train/png/[Privious]WGAN_VGG_test/low2high/' \
--validate-every 1 \
--num_workers 4 \
--criterion_mode 'not balance' \
--teacher_forcing "False" \
--patch_training "True" \
--multi-gpu-mode 'Single' \
--resume '/workspace/sunggu/4.Dose_img2img/model/[Privious]WGAN_VGG_test/epoch_716_checkpoint.pth'
# --multi-gpu-mode 'DataParallel' \
# Out:
# inintializing...!
# inintializing...!
# inintializing...!
# inintializing...!
# inintializing...!
# inintializing...!
# inintializing...!
# inintializing...!
# inintializing...!
# inintializing...!
# inintializing...!
# inintializing...!
# inintializing...!
# ***********************************************
# ***********************************************
# Dataset Name:  Sinogram_DCM
# ---------- Model ----------
# Resume From:  /workspace/sunggu/4.Dose_img2img/model/[Privious]WGAN_VGG_test/epoch_716_checkpoint.pth
# Output To:  /workspace/sunggu/4.Dose_img2img/model/[Privious]WGAN_VGG_test
# Save   To:  /workspace/sunggu/4.Dose_img2img/Predictions/Train/png/[Privious]WGAN_VGG_test/low2high/
# ---------- Optimizer ----------
# Learning Rate:  0.0002
# Weight Decay:  0.05
# Batchsize:  160
# Loading dataset ....
# Train [Total]  number =  6899
# Valid [Total]  number =  14
# Creating model: WGAN_VGG
# Number of Learnable Params: 27780386
# Loading pre-trained Weight...!
# ...

# %%
def dicom_normalize(image, MIN_HU=-1024.0, MAX_HU=3071.0):   # I already check the max value is 3071.0
   image = (image - MIN_HU) / (MAX_HU - MIN_HU)   # Range  0.0 ~ 1.0
#    image = (image - 0.5) / 0.5                  # Range -1.0 ~ 1.0   @ We do not use -1~1 range becuase there is no Tanh act.
   return image

# %%
dicom_normalize(80)
# Out:
# 0.2695970695970696

# %%
dicom_normalize(0)
# Out:
# 0.25006105006105006

# %%
def dicom_denormalize(image, MIN_HU=-1024.0, MAX_HU=3071.0):
    # image = (image - 0.5) / 0.5           # Range -1.0 ~ 1.0   @ We do not use -1~1 range becuase there is no Tanh act.
    image = (MAX_HU - MIN_HU)*image + MIN_HU
    return image

# %%
p = np.load('/workspace/sunggu/4.Dose_img2img/WGAN_VGG_output1.npy')
g = np.load('/workspace/sunggu/4.Dose_img2img/input_n_201.npy')

# %%
_=plt.hist(p.flatten(), bins='auto')

# %%
_=plt.hist(g.flatten(), bins='auto')

# %%
dicom_denormalize(0.25)
# Out:
# -0.25

# %%
plt.figure(figsize=(16,16))

plt.subplot(121)
plt.imshow(dicom_denormalize(g).squeeze(), 'gray', vmin=-1024, vmax=100)

plt.subplot(122)
plt.imshow(dicom_denormalize(p).squeeze(), 'gray', vmin=-1024, vmax=100)

plt.show()

# %%
plt.figure(figsize=(16,16))

plt.subplot(121)
plt.imshow(g.squeeze(), 'gray')

plt.subplot(122)
plt.imshow(p.squeeze(), 'gray')

plt.show()
